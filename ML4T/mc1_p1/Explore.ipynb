# %%
import util
import pandas as pd
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
dates = pd.date_range('20050101','20120301',freq="D")
stocks = util.get_data(['GOOG','AAPL','MSFT'], dates)
util.plot_data(stocks)

# %%
(stocks/stocks.iloc[0,:]).plot()

# %%
stocks.plot()
